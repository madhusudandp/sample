# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
pip install -U pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
ls -l
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7ED4-C196
#
#  Directory of C:\Users\Madhu Sudhan\Downloads
#
#
#  Directory of C:\Users\Madhu Sudhan\Downloads
# File Not Found

# %%
import pandas as pd
df = pd.read_csv('bikes.csv') 
#     for i in range(3):
#         print(f.readline())  
df.head(10)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 0    Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1    Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 3    Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
# 4    Male  2013-07-01 11:16:00  2013-07-01 11:18:00           130
# 5    Male  2013-07-01 12:37:00  2013-07-01 12:48:00           660
# 6    Male  2013-07-02 17:47:00  2013-07-02 17:56:00           565
# 7    Male  2013-07-03 09:07:00  2013-07-03 09:16:00           505
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 9  Female  2013-07-04 15:00:00  2013-07-04 15:16:00           922
#
#                from_station_name  start_capacity  \
# 0      Lake Shore Dr & Monroe St            11.0
# 1   Clinton St & Washington Blvd            31.0
# 2   Sheffield Ave & Kingsbury St            15.0
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Madhu Sudhan\\Downloads'

# %%
df=pd.read_csv(r"C:\Users\Madhu Sudhan\Desktop\Jupyter Notebooks\data\college.csv")

# %%
df.head(10)
# Out:
#                                 instnm            city stabbr  hbcu  menonly  \
# 0             Alabama A & M University          Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# 2                   Amridge University      Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# 4             Alabama State University      Montgomery     AL   1.0      0.0
# 5            The University of Alabama      Tuscaloosa     AL   0.0      0.0
# 6    Central Alabama Community College  Alexander City     AL   0.0      0.0
# 7              Athens State University          Athens     AL   0.0      0.0
# 8      Auburn University at Montgomery      Montgomery     AL   0.0      0.0
# 9                    Auburn University          Auburn     AL   0.0      0.0
#
#    womenonly  relaffil  satvrmid  satmtmid  distanceonly  ...  ugds_2mor  \
# ...
