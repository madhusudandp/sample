# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >\[*pandas*\] is derived from the term "**pan**el **da**ta", an econometrics term for data sets that include observations over multiple time periods for the same individuals. — [Wikipedia](https://en.wikipedia.org/wiki/Pandas_%28software%29)

# %% [markdown]
# - pandas is package / library in Python and the most important tool for data analysts / data scientists
# - Powerful ML and visualization tools work on the back of pandas
#     - **pandas is the backbone of most data projects**

# %% [markdown]
# ### Core components of pandas: Series & DataFrame

# %% [markdown]
# - A series is essentially a `column`, and a DataFrame is a multi-dimensional table made up of collection of series

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Create Series

# %% [markdown]
# #### From ndarray

# %%
arr = np.random.randn(5)
print(arr)
# Out:
# [-2.15983289 -0.62710126 -0.32549202  2.0598737   0.08156173]

# %% [markdown]
# `pd.Series()` : `Do not miss the capital 'S'`

# %%
pd_series = pd.Series(arr) #convert an array into Pandas series

# %%
pd_series
# Out:
# 0   -2.159833
# 1   -0.627101
# 2   -0.325492
# 3    2.059874
# 4    0.081562
# dtype: float64

# %%
print(type(pd_series))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #### Set the own index

# %%
pd_series = pd.Series(arr,index=['a', 'b', 'c','d','e'] ) #convert an array into Pandas series
pd_series
# Out:
# a   -2.159833
# b   -0.627101
# c   -0.325492
# d    2.059874
# e    0.081562
# dtype: float64

# %%
pd_series = pd.Series(arr,index=['a', 'b', 'c','d','e'] , name="My_First_Random_Pandas_Series") #convert an array into Pandas series
pd_series
# Out:
# a   -2.159833
# b   -0.627101
# c   -0.325492
# d    2.059874
# e    0.081562
# Name: My_First_Random_Pandas_Series, dtype: float64

# %%
pd_series = pd.Series(arr,index=['a', 'b', 'c','d','e'] , name="My_First_Random_Pandas_Series") #convert an array into Pandas series
pd_series
# Out:
# a   -2.159833
# b   -0.627101
# c   -0.325492
# d    2.059874
# e    0.081562
# Name: My_First_Random_Pandas_Series, dtype: float64

# %%
arr1 = np.array(list(range(10,20,2)))
print(arr1)
# Out:
# [10 12 14 16 18]

# %%
pd_series_1 = pd.Series(arr1, dtype='float64')
print(pd_series_1)
# Out:
# 0    10.0
# 1    12.0
# 2    14.0
# 3    16.0
# 4    18.0
# dtype: float64

# %%
madict={'madhu':27,'arun':28,'madhu':28}

# %%
madict
# Out:
# {'madhu': 28, 'arun': 28}

# %%
madict('madhu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 madict('madhu')
#
# TypeError: 'dict' object is not callable

# %%
score={'madhu':98,'akash':75,'ramesh':72,'stalin':75,'abdul':87}

# %%
import pandas as pd

# %%
score
# Out:
# {'madhu': 98, 'akash': 75, 'ramesh': 72, 'stalin': 75, 'abdul': 87}

# %%
pd_score=pd.Series(score)

# %%
pd_score
# Out:
# madhu     98
# akash     75
# ramesh    72
# stalin    75
# abdul     87
# dtype: int64

# %%
max(pd_score)
# Out:
# 98

# %%
creteria=(pd_score>70) & (pd_score<80)

# %%
creteria
# Out:
# madhu     False
# akash      True
# ramesh     True
# stalin     True
# abdul     False
# dtype: bool

# %%
pd_score["madhu"]
# Out:
# 98

# %%
print(pd_score.max())
print(pd_score.min())
print(pd_score.mean())
print(pd_score.median())
print(pd_score.var())
print(pd_score.std())
print(pd_score.mode())
# Out:
# 98
# 72
# 81.4
# 75.0
# 119.30000000000003
# 10.92245393673052
# 0    75
# dtype: int64

# %%
pd_score.max()
# Out:
# 98

# %%
pd_score.index
# Out:
# Index(['madhu', 'akash', 'ramesh', 'stalin', 'abdul'], dtype='object')

# %%
pd_score.shape
# Out:
# (5,)

# %%
pd_score.dtype
# Out:
# dtype('int64')

# %%
pd_score.size
# Out:
# 5

# %%
pd_score.empty
# Out:
# False

# %%
pd_score.hasnans
# Out:
# False

# %%
pd_score.nbytes
# Out:
# 40

# %%
pd_score.ndim
# Out:
# 1

# %%
score1={'madhu':98,'akash':75,'ramesh':72,'stalin':75,'abdul':" "}

# %%
pd1=pd.Series(score1)

# %%
pd1
# Out:
# madhu     98
# akash     75
# ramesh    72
# stalin    75
# abdul
# dtype: object

# %%
pd1.empty
# Out:
# False

# %%
pd1.hasnans
# Out:
# False

# %%
pd1.isna()
# Out:
# madhu     False
# akash     False
# ramesh    False
# stalin    False
# abdul     False
# dtype: bool

# %%
pd1.isnull()
# Out:
# madhu     False
# akash     False
# ramesh    False
# stalin    False
# abdul     False
# dtype: bool

# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Madhu Sudhan\\Downloads'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.opera',
#  '02-05_Numpy HandsOn.ipynb',
#  '5th-AprilPython-basics (1).ipynb',
#  '5th-AprilPython-basics (1).zip',
#  '5th-AprilPython-basics.ipynb',
#  '5th-AprilPython-basics.zip',
#  '6 Healthy Habits That Make You Mentally Strong.mp4',
#  '6th April(Python basics).ipynb',
#  '7th April(Python basics).ipynb',
#  '7th-AprilPython-basics.zip',
#  'assignment 4.zip',
#  'Assignment-SQL-Queries-1 (1).pdf',
#  'Assignment-SQL-Queries-1.pdf',
#  'assinment 3.rar',
#  'bike-sharing-demand.csv',
#  'BraveBrowserSetup-BRV010.exe',
#  'Create-use-drop-database.pdf',
#  'Data-Set-2.zip',
#  'Dec17-Handson (1).zip',
#  'Dec17-Handson.zip',
#  'Demo1.zip',
#  'Demo2.zip',
#  'desktop.ini',
#  'DiscordSetup.exe',
#  'download.jpg',
#  'FIT.jpg',
#  'for yt.jpg',
#  'Funny Baby Videos eating  # Short.mp4',
#  'hq720.webp',
#  'IIF-function-in-sql.pdf',
#  'IMDB-Movie-Data.csv',
#  'Inheritance diagrams - Copy.pdf',
#  'intellipaat-certificate.pdf',
#  'Intro_to_Numpy.pdf',
#  'Invoice -ISSPL21-22041224.pdf',
#  'Invoice-B2C2223IN18617.pdf',
#  'Iris.csv',
#  'linux-28th-march.zip',
#  'M01-LS-Data_Manipulation_with_NumPy_14Jun_Part-02_APC.ipynb',
#  'M01-LS-Data_Manipulation_with_NumPy_15Jun_Part-03_APC.ipynb',
#  'M01-LS-Data_Manipulation_with_NumPy_16Jun_Part-04_APC.ipynb',
#  'M01-LS-Data_Manipulation_with_NumPy_Final_22Jun_APC.ipynb',
#  'M02-LS-Data_Manipulation_with_Pandas_22Jun_Part-01_APC.ipynb',
#  'madhu_sql_mod2.rar',
#  'Microsoft SQL Installation.pdf',
#  'Microsoft-SQL-Installation-2.zip',
#  'MobaXterm_Installer_v23.0.zip',
#  'Module-1-File-1.pdf',
#  'Module-3-File-1 (7).pdf',
#  'module0.py',
#  'module1 (1).py',
#  'module1.py',
#  'mudel1.py',
#  'Oops- 13th april .ipynb',
#  'Oops-11th-april-.zip',
#  'Oops-13th-april-',
#  'Oops-13th-april-.zip',
#  'PGP-in-Data-Science-and-Machine-Learning-Job-Guarantee-Program.pdf',
#  'Placement_Data_Full_Class.csv',
#  'Product.zip',
#  'Python-Basics-Assignment-3.pdf',
#  'python-Datasets.zip',
#  'sql assignment 4 and 5.zip',
#  'SQL-Certificate_SQL-Workshop-Quiz_Madhusudana-D-P (1).pdf',
#  'SQL-Certificate_SQL-Workshop-Quiz_Madhusudana-D-P.pdf',
#  'sql-developer-mod-5-3 (1).pdf',
#  'sql-developer-mod-5-3 (2).pdf',
#  'sql-developer-mod-5-3.pdf',
#  'SQL-inner-join.pdf',
#  'SQL-merge.pdf',
#  'SQL-Module-2.pdf',
#  'SQL-Module-3 (1).pdf',
#  'SQL-Module-3.pdf',
#  'SQL-Module-4 (1).pdf',
#  'SQL-Module-4.pdf',
#  'SQL-New-Assignment-2 (1).pdf',
#  'SQL-New-Assignment-2.pdf',
#  'SQL-New-Assignment.rar',
#  'Storytelling_with_data_Cole.pdf',
#  'untitled',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'vpnkitsetup.exe',
#  'yt1s.com - 6 Signs Youre Burnt Out Not Lazy.mp4',
#  'yt1s.com - 9 Habits That Keep You Mentally Happy.mp4',
#  'yt1s.com - Baby Sloths Being Sloths  FUNNIEST Compilation.mp4',
#  'yt1s.com - How to Stay Motivated in Your 20s  Sadhguru Answers.mp4',
#  '~$crosoft SQL Installation.pdf',
#  '~$en-uri20220606-6477-g2u1vp.pdf']

# %%
df_imdb=pd.read_csv("IMDB-Movie-Data.csv")
df_imdb
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 995                111     6.2   27585                 NaN       45.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 998                 93     5.6    4881                 NaN       22.0
# 999                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 12 columns]

# %%
                df_imdb.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %%
df_imdb.head(3).T
# Out:
#                                                                     0  \
# Rank                                                                1
# Title                                         Guardians of the Galaxy
# Genre                                         Action,Adventure,Sci-Fi
# Description         A group of intergalactic criminals are forced ...
# Director                                                   James Gunn
# Actors              Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                             2014
# Runtime (Minutes)                                                 121
# Rating                                                            8.1
# Votes                                                          757074
# Revenue (Millions)                                             333.13
# Metascore                                                        76.0
#
#                                                                     1  \
# Rank                                                                2
# Title                                                      Prometheus
# Genre                                        Adventure,Mystery,Sci-Fi
# Description         Following clues to the origin of mankind, a te...
# Director                                                 Ridley Scott
# Actors              Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Year                                                             2012
# Runtime (Minutes)                                                 124
# Rating                                                            7.0
# Votes                                                          485820
# Revenue (Millions)                                             126.46
# Metascore                                                        65.0
#
#                                                                     2
# Rank                                                                3
# Title                                                           Split
# Genre                                                 Horror,Thriller
# Description         Three girls are kidnapped by a man with a diag...
# Director                                           M. Night Shyamalan
# Actors              James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                             2016
# Runtime (Minutes)                                                 117
# Rating                                                            7.3
# Votes                                                          157606
# Revenue (Millions)                                             138.12
# Metascore                                                        62.0

# %%
df_imdb.tail().T
# Out:
#                                                                   995  \
# Rank                                                              996
# Title                                            Secret in Their Eyes
# Genre                                             Crime,Drama,Mystery
# Description         A tight-knit team of rising investigators, alo...
# Director                                                    Billy Ray
# Actors              Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Year                                                             2015
# Runtime (Minutes)                                                 111
# Rating                                                            6.2
# Votes                                                           27585
# Revenue (Millions)                                                NaN
# Metascore                                                        45.0
#
#                                                                   996  \
# Rank                                                              997
# Title                                                 Hostel: Part II
# Genre                                                          Horror
# Description         Three American college students studying abroa...
# Director                                                     Eli Roth
# Actors              Lauren German, Heather Matarazzo, Bijou Philli...
# Year                                                             2007
# Runtime (Minutes)                                                  94
# Rating                                                            5.5
# Votes                                                           73152
# Revenue (Millions)                                              17.54
# Metascore                                                        46.0
#
#                                                                   997  \
# Rank                                                              998
# Title                                          Step Up 2: The Streets
# Genre                                             Drama,Music,Romance
# Description         Romantic sparks occur between two dance studen...
# Director                                                   Jon M. Chu
# Actors              Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Year                                                             2008
# Runtime (Minutes)                                                  98
# Rating                                                            6.2
# Votes                                                           70699
# Revenue (Millions)                                              58.01
# Metascore                                                        50.0
#
#                                                                   998  \
# Rank                                                              999
# Title                                                    Search Party
# Genre                                                Adventure,Comedy
# Description         A pair of friends embark on a mission to reuni...
# Director                                               Scot Armstrong
# Actors              Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Year                                                             2014
# Runtime (Minutes)                                                  93
# Rating                                                            5.6
# Votes                                                            4881
# Revenue (Millions)                                                NaN
# Metascore                                                        22.0
#
#                                                                   999
# Rank                                                             1000
# Title                                                      Nine Lives
# Genre                                           Comedy,Family,Fantasy
# Description         A stuffy businessman finds himself trapped ins...
# Director                                             Barry Sonnenfeld
# Actors              Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Year                                                             2016
# Runtime (Minutes)                                                  87
# Rating                                                            5.3
# Votes                                                           12435
# Revenue (Millions)                                              19.64
# Metascore                                                        11.0

# %%
df_imdb.sample(3)
# Out:
#      Rank                     Title                     Genre  \
# 644   645                     Viral       Drama,Horror,Sci-Fi
# 853   854  Vicky Cristina Barcelona             Drama,Romance
# 20     21                      Gold  Adventure,Drama,Thriller
#
#                                            Description        Director  \
# 644  Following the outbreak of a virus that wipes o...     Henry Joost
# 853  Two girlfriends on a summer holiday in Spain b...     Woody Allen
# 20   Kenny Wells, a prospector desperate for a luck...  Stephen Gaghan
#
#                                                 Actors  Year  \
# 644  Sofia Black-D'Elia, Analeigh Tipton,Travis Top...  2016
# 853  Rebecca Hall, Scarlett Johansson, Javier Barde...  2008
# 20   Matthew McConaughey, Edgar Ramírez, Bryce Dall...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 644                 85     5.5    3564                 NaN       72.0
# 853                 96     7.1  208770               23.21       70.0
# 20                 120     6.7   19053                7.22       49.0

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df_imdb.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# 2                False   False  False               False      False
# 3                False   False  False               False      False
# 4                False   False  False               False      False
# ..                 ...     ...    ...                 ...        ...
# 995              False   False  False                True      False
# 996              False   False  False               False      False
# 997              False   False  False               False      False
# 998              False   False  False                True      False
# 999              False   False  False               False      False
#
# [1000 rows x 12 columns]

# %%
df_imdb.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df_imdb.isnull().sum()/len(df_imdb)*100
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
len(df_imdb)
# Out:
# 1000

# %%
df_imdb['Revenue (Millions)']
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
df_imdb['Revenue (Millions)'].mean()
# Out:
# 82.95637614678897

# %%
df_imdb_copy=df_imdb.copy()

# %%
df_imdb_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df_imdb_copy.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
df_imdb_notnull=df_imdb.dropna()

# %%
df_imdb_notnull.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df_imdb_notnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Title               838 non-null    object
#  2   Genre               838 non-null    object
#  3   Description         838 non-null    object
#  4   Director            838 non-null    object
#  5   Actors              838 non-null    object
#  6   Year                838 non-null    int64
#  7   Runtime (Minutes)   838 non-null    int64
#  8   Rating              838 non-null    float64
#  9   Votes               838 non-null    int64
#  10  Revenue (Millions)  838 non-null    float64
#  11  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.1+ KB

# %%
df_imdb.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
df_imdb.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df_imdb.max['Genre']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 df_imdb.max['Genre']
#
# TypeError: 'method' object is not subscriptable

# %%
df_imdb['Genre'].max()
# Out:
# 'Thriller,War'

# %%
df_imdb['Genre'].value_counts()
# Out:
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Action,Comedy,Family        1
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Family,Fantasy       1
# Name: Genre, Length: 207, dtype: int64

# %%
df_imdb['Genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
df_imdb['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
#        'Crime,Drama,Mystery', 'Drama,Romance,Thriller',
#        'Drama,History,Thriller', 'Action,Drama,Thriller', 'Drama,History',
#        'Action,Drama,Romance', 'Drama,Fantasy', 'Action,Sci-Fi',
#        'Adventure,Drama,War', 'Action,Comedy,Fantasy',
#        'Biography,Comedy,Crime', 'Crime,Drama', 'Comedy,Crime,Drama',
#        'Action,Comedy,Crime', 'Animation,Drama,Fantasy',
#        'Horror,Mystery,Sci-Fi', 'Drama,Mystery,Thriller',
#        'Crime,Drama,Thriller', 'Biography,Crime,Drama',
#        'Crime,Mystery,Thriller', 'Action,Horror,Thriller',
#        'Romance,Sci-Fi', 'Action,Fantasy,War', 'Action,Biography,Drama',
#        'Drama,Horror,Mystery', 'Adventure,Drama,Family',
#        'Adventure,Comedy,Romance', 'Action', 'Adventure,Crime,Mystery',
#        'Comedy,Family,Musical', 'Adventure,Comedy,Drama',
#        'Drama,Horror,Thriller', 'Drama,Music', 'Mystery,Thriller',
#        'Mystery,Thriller,Western', 'Comedy,Family',
#        'Biography,Comedy,Drama', 'Drama,Western', 'Drama,Mystery,Romance',
#        'Action,Drama,Mystery', 'Action,Adventure,Crime',
#        'Adventure,Sci-Fi,Thriller', 'Action,Comedy,Mystery',
#        'Thriller,War', 'Action,Adventure,Thriller',
#        'Drama,Fantasy,Romance', 'Action,Drama,History',
#        'Animation,Adventure,Family', 'Adventure,Horror',
#        'Drama,Romance,Sci-Fi', 'Action,Adventure,Family', 'Action,Comedy',
#        'Comedy,Romance', 'Horror,Mystery', 'Drama,Family,Fantasy',
#        'Sci-Fi', 'Drama,War', 'Drama,Fantasy,Horror',
#        'Crime,Drama,History', 'Horror,Sci-Fi,Thriller',
#        'Action,Drama,Sport', 'Adventure,Biography,Drama',
#        'Biography,Drama,Thriller', 'Action,Adventure,Mystery',
#        'Drama,Horror', 'Comedy,Crime', 'Drama,Fantasy,War',
#        'Action,Adventure,Romance', 'Action,Drama,War',
#        'Drama,Musical,Romance', 'Drama,Sci-Fi,Thriller',
#        'Action,Drama,Sci-Fi', 'Drama,Sci-Fi', 'Adventure,Fantasy',
#        'Thriller', 'Biography,Drama,Romance', 'Action,Adventure',
#        'Action,Fantasy', 'Action,Drama,Horror', 'Comedy,Music,Romance',
#        'Biography,Drama,Sport', 'Action,Horror', 'Comedy,Horror,Thriller',
#        'Crime,Drama,Music', 'Action,Sci-Fi,Thriller',
#        'Drama,Horror,Sci-Fi', 'Drama,Sport', 'Comedy,Horror',
#        'Comedy,Fantasy,Romance', 'Comedy,Fantasy', 'Comedy,Drama,Fantasy',
#        'Adventure,Comedy,Horror', 'Comedy,Mystery',
#        'Action,Mystery,Sci-Fi', 'Action,Crime,Fantasy',
#        'Comedy,Fantasy,Horror', 'Animation,Action,Adventure',
#        'Action,Comedy,Family', 'Comedy,Sci-Fi', 'Action,Biography,Crime',
#        'Adventure,Comedy', 'Comedy,Music', 'Comedy,Drama,Horror',
#        'Action,Horror,Romance', 'Action,Drama,Fantasy',
#        'Action,Mystery,Thriller', 'Action,Adventure,Horror',
#        'Animation,Family,Fantasy', 'Adventure,Horror,Mystery',
#        'Action,Horror,Mystery', 'Adventure,Comedy,Family',
#        'Action,Crime,Mystery', 'Comedy,Drama,Family',
#        'Action,Crime,Sport', 'Mystery,Sci-Fi,Thriller', 'Sci-Fi,Thriller',
#        'Adventure,Drama,Horror', 'Biography,History,Thriller',
#        'Adventure,Comedy,Sci-Fi', 'Fantasy,Horror',
#        'Action,Fantasy,Thriller', 'Comedy,Romance,Sport',
#        'Animation,Action,Comedy', 'Drama,Fantasy,Thriller',
#        'Action,Comedy,Romance', 'Action,Fantasy,Horror',
#        'Mystery,Romance,Sci-Fi', 'Comedy,Drama,Thriller',
#        'Comedy,Western', 'Drama,History,War', 'Fantasy,Horror,Thriller',
#        'Drama,Horror,Musical', 'Drama,Family', 'Romance,Sci-Fi,Thriller',
#        'Animation,Fantasy', 'Drama,Mystery,War', 'Action,Drama,Family',
#        'Adventure,Drama,Western', 'Drama,Music,Romance',
#        'Comedy,Romance,Western', 'Adventure,Drama', 'Drama,Thriller,War',
#        'Drama,Fantasy,Mystery', 'Comedy,Crime,Thriller',
#        'Animation,Comedy,Drama', 'Action,Comedy,Sci-Fi',
#        'Drama,Romance,War', 'Adventure,Fantasy,Mystery',
#        'Mystery,Romance,Thriller', 'Biography,Drama,Mystery',
#        'Animation,Drama,Romance', 'Comedy,Horror,Romance',
#        'Action,Thriller,War', 'Action,Comedy,Horror',
#        'Action,Crime,Sci-Fi', 'Crime,Thriller', 'Comedy,Horror,Sci-Fi',
#        'Crime,Drama,Fantasy', 'Drama,Fantasy,Music',
#        'Action,Comedy,Sport', 'Fantasy,Mystery,Thriller', 'Adventure',
#        'Adventure,Biography', 'Adventure,Biography,Crime',
#        'Comedy,Drama,Musical', 'Comedy,Family,Romance',
#        'Biography,Drama,Family', 'Drama,Fantasy,Musical',
#        'Adventure,Family', 'Adventure,Comedy,Fantasy',
#        'Drama,Family,Music', 'Comedy,Family,Fantasy'], dtype=object)

# %%
df_imdb.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df_imdb[['Rank','Title']]
# Out:
#      Rank                    Title
# 0       1  Guardians of the Galaxy
# 1       2               Prometheus
# 2       3                    Split
# 3       4                     Sing
# 4       5            Suicide Squad
# ..    ...                      ...
# 995   996     Secret in Their Eyes
# 996   997          Hostel: Part II
# 997   998   Step Up 2: The Streets
# 998   999             Search Party
# 999  1000               Nine Lives
#
# [1000 rows x 2 columns]

# %%
new_col=['Runtime (Minutes)', 'Rating', 'Votes']

# %%
df_imdb[new_col]
# Out:
#      Runtime (Minutes)  Rating   Votes
# 0                  121     8.1  757074
# 1                  124     7.0  485820
# 2                  117     7.3  157606
# 3                  108     7.2   60545
# 4                  123     6.2  393727
# ..                 ...     ...     ...
# 995                111     6.2   27585
# 996                 94     5.5   73152
# 997                 98     6.2   70699
# 998                 93     5.6    4881
# 999                 87     5.3   12435
#
# [1000 rows x 3 columns]

# %%
print("revenue in $:",df_imdb['Revenue (Millions)'].sum())
# Out:
# revenue in $: 72337.95999999999

# %%
df_imdb.loc[df_imdb['Title']=='The Dark Knight']
# Out:
#     Rank            Title               Genre  \
# 54    55  The Dark Knight  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#     Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                152     9.0  1791916              533.32       82.0

# %%
df_imdb.iloc[54]
# Out:
# Rank                                                                 55
# Title                                                   The Dark Knight
# Genre                                                Action,Crime,Drama
# Description           When the menace known as the Joker wreaks havo...
# Director                                              Christopher Nolan
# Actors                Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
# Year                                                               2008
# Runtime (Minutes)                                                   152
# Rating                                                              9.0
# Votes                                                           1791916
# Revenue (Millions)                                               533.32
# Metascore                                                          82.0
# Name: 54, dtype: object

# %%
df_imdb.iloc[0:10 ,:3]
# Out:
#    Rank                    Title                       Genre
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance

# %%
search=df_imdb['Title'].str.contains('titanic',case=False)

# %%
search
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Title, Length: 1000, dtype: bool

# %%
df_imdb[search]
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Genre, Description, Director, Actors, Year, Runtime (Minutes), Rating, Votes, Revenue (Millions), Metascore]
# Index: []

# %%
df_imdb.iloc[124,3]
# Out:
# "Eight years after the Joker's reign of anarchy, the Dark Knight, with the help of the enigmatic Selina, is forced from his imposed exile to save Gotham City, now on the edge of total annihilation, from the brutal guerrilla terrorist Bane."

# %%
search=df_imdb['Director'].str.contains('Nolan',case=False)

# %%
search
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Director, Length: 1000, dtype: bool

# %%
df_imdb[search]
# Out:
#      Rank                  Title                    Genre  \
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 54     55        The Dark Knight       Action,Crime,Drama
# 64     65           The Prestige     Drama,Mystery,Sci-Fi
# 80     81              Inception  Action,Adventure,Sci-Fi
# 124   125  The Dark Knight Rises          Action,Thriller
#
#                                            Description           Director  \
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 64   Two stage magicians engage in competitive one-...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
#
#                                                 Actors  Year  \
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 64   Christian Bale, Hugh Jackman, Scarlett Johanss...  2006
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 36                 169     8.6  1047747              187.99       74.0
# 54                 152     9.0  1791916              533.32       82.0
# 64                 130     8.5   913152               53.08       66.0
# 80                 148     8.8  1583625              292.57       74.0
# 124                164     8.5  1222645              448.13       78.0

# %%
filter_ch=(df_imdb['Director']=='Christopher Nolan') & (df_imdb['Year']>2010)

# %%
df_imdb[filter_ch]
# Out:
#      Rank                  Title                   Genre  \
# 36     37           Interstellar  Adventure,Drama,Sci-Fi
# 124   125  The Dark Knight Rises         Action,Thriller
#
#                                            Description           Director  \
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
#
#                                                 Actors  Year  \
# 36   Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 36                 169     8.6  1047747              187.99       74.0
# 124                164     8.5  1222645              448.13       78.0

# %%
df_student = pd.DataFrame({
    'stu_id': [1,2,3,4],
    'name':['Akash', 'Kavitha', 'Varun','Nitish']
})
df_student_info = pd.DataFrame({
    'stu_id': [1,2,3,4,5,6,7],
    'age':[34,20,21,18,25,20,18],
    'sex': ['M','F','M','M','F','M','M']
})

# %%
df_student
# Out:
#    stu_id     name
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish

# %%
df_student_info
# Out:
#    stu_id  age sex
# 0       1   34   M
# 1       2   20   F
# 2       3   21   M
# 3       4   18   M
# 4       5   25   F
# 5       6   20   M
# 6       7   18   M

# %%
pd.merge(df_student,df_student_info)
# Out:
#    stu_id     name  age sex
# 0       1    Akash   34   M
# 1       2  Kavitha   20   F
# 2       3    Varun   21   M
# 3       4   Nitish   18   M

# %%
pd.merge(df_student_info,df_student)
# Out:
#    stu_id  age sex     name
# 0       1   34   M    Akash
# 1       2   20   F  Kavitha
# 2       3   21   M    Varun
# 3       4   18   M   Nitish

# %%
import os
import pandas as pd

# %%
df_sample=pd.read_csv("Sample_-_Superstore.csv")

# %%
df_sample.head(5).T
# Out:
#                                                    0  \
# Category                                   Furniture
# City                                       Henderson
# Country                                United States
# Customer Name                            Claire Gute
# Discount                                         0.0
# Number of Records                                  1
# Order Date                                 11/8/2017
# Order ID                              CA-2017-152156
# Postal Code                                  42420.0
# Manufacturer                                    Bush
# Product Name       Bush Somerset Collection Bookcase
# Profit                                       41.9136
# Quantity                                           2
# Region                                         South
# Sales                                         261.96
# Segment                                     Consumer
# Ship Date                                 11/11/2017
# Ship Mode                               Second Class
# State                                       Kentucky
# Sub-Category                               Bookcases
#
#                                                                    1  \
# Category                                                   Furniture
# City                                                       Henderson
# Country                                                United States
# Customer Name                                            Claire Gute
# Discount                                                         0.0
# Number of Records                                                  1
# Order Date                                                 11/8/2017
# Order ID                                              CA-2017-152156
# Postal Code                                                  42420.0
# Manufacturer                                                     Hon
# Product Name       Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Profit                                                       219.582
# Quantity                                                           3
# Region                                                         South
# Sales                                                         731.94
# Segment                                                     Consumer
# Ship Date                                                 11/11/2017
# Ship Mode                                               Second Class
# State                                                       Kentucky
# Sub-Category                                                  Chairs
#
#                                                                    2  \
# Category                                             Office Supplies
# City                                                     Los Angeles
# Country                                                United States
# Customer Name                                        Darrin Van Huff
# Discount                                                         0.0
# Number of Records                                                  1
# Order Date                                                 6/12/2017
# Order ID                                              CA-2017-138688
# Postal Code                                                  90036.0
# Manufacturer                                               Universal
# Product Name       Self-Adhesive Address Labels for Typewriters b...
# Profit                                                        6.8714
# Quantity                                                           2
# Region                                                          West
# Sales                                                          14.62
# Segment                                                    Corporate
# Ship Date                                                  6/16/2017
# Ship Mode                                               Second Class
# State                                                     California
# Sub-Category                                                  Labels
#
#                                                                3  \
# Category                                               Furniture
# City                                             Fort Lauderdale
# Country                                            United States
# Customer Name                                     Sean O'Donnell
# Discount                                                    0.45
# Number of Records                                              1
# Order Date                                            10/11/2016
# Order ID                                          US-2016-108966
# Postal Code                                              33311.0
# Manufacturer                                            Bretford
# Product Name       Bretford CR4500 Series Slim Rectangular Table
# Profit                                                  -383.031
# Quantity                                                       5
# Region                                                     South
# Sales                                                   957.5775
# Segment                                                 Consumer
# Ship Date                                             10/18/2016
# Ship Mode                                         Standard Class
# State                                                    Florida
# Sub-Category                                              Tables
#
#                                                 4
# Category                          Office Supplies
# City                              Fort Lauderdale
# Country                             United States
# Customer Name                      Sean O'Donnell
# Discount                                      0.2
# Number of Records                               1
# Order Date                             10/11/2016
# Order ID                           US-2016-108966
# Postal Code                               33311.0
# Manufacturer                                Eldon
# Product Name       Eldon Fold 'N Roll Cart System
# Profit                                     2.5164
# Quantity                                        2
# Region                                      South
# Sales                                      22.368
# Segment                                  Consumer
# Ship Date                              10/18/2016
# Ship Mode                          Standard Class
# State                                     Florida
# Sub-Category                              Storage

# %%
df_sample.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer Name', 'Discount',
#        'Number of Records', 'Order Date', 'Order ID', 'Postal Code',
#        'Manufacturer', 'Product Name', 'Profit', 'Quantity', 'Region', 'Sales',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category'],
#       dtype='object')

# %%
df_sample.groupby('Category')['Sales'].sum().reset_index()
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
df_sample.groupby('Sub-Category')['Sales'].sum().reset_index()
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
df_sample.groupby('Sub-Category')['Sales']['Profit'].sum()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 df_sample.groupby('Sub-Category')['Sales']['Profit'].sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\base.py:235, in SelectionMixin.__getitem__(self, key)
#     233 def __getitem__(self, key):
#     234     if self._selection is not None:
# --> 235         raise IndexError(f"Column(s) {self._selection} already selected")
#     237     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     238         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) Sales already selected

# %%
df_sample.sort_values(by='Profit', ascending=False) #High to Low
# Out:
#              Category         City        Country   Customer Name  Discount  \
# 8093       Technology    Lafayette  United States    Tamara Chand       0.0
# 4905       Technology      Seattle  United States    Raymond Buch       0.0
# 5297       Technology       Newark  United States    Hunter Lopez       0.0
# 3273  Office Supplies      Detroit  United States   Adrian Barton       0.0
# 3232  Office Supplies  Minneapolis  United States    Sanjit Chand       0.0
# ...               ...          ...            ...             ...       ...
# 7101  Office Supplies      Chicago  United States   Henry Goldwyn       0.8
# 9993       Technology   Louisville  United States  Sharelle Roach       0.7
# 3558  Office Supplies  San Antonio  United States     Luke Foster       0.8
# 683        Technology   Burlington  United States  Grant Thornton       0.5
# 5398       Technology    Lancaster  United States   Cindy Stewart       0.7
#
#       Number of Records  Order Date        Order ID  Postal Code Manufacturer  \
# 8093                  1   10/2/2017  CA-2017-118689      47905.0        Canon
# 4905                  1   3/23/2018  CA-2018-140151      98115.0        Canon
# 5297                  1  11/17/2018  CA-2018-166709      19711.0        Canon
# 3273                  1  12/17/2017  CA-2017-117121      48205.0          GBC
# 3232                  1   9/23/2015  CA-2015-116904      55407.0        Ibico
# ...                 ...         ...             ...          ...          ...
# 7101                  1   12/7/2018  US-2018-122714      60653.0        Ibico
# 9993                  1   4/17/2018  CA-2018-134845      80027.0        Other
# 3558                  1   7/26/2015  CA-2015-169019      78207.0          GBC
# 683                   1   11/4/2018  US-2018-168116      27217.0       Cubify
# 5398                  1  11/25/2017  CA-2017-108196      43130.0       Cubify
#
#                                           Product Name     Profit  Quantity  \
# 8093             Canon imageCLASS 2200 Advanced Copier  8399.9760         5
# 4905             Canon imageCLASS 2200 Advanced Copier  6719.9808         4
# 5297             Canon imageCLASS 2200 Advanced Copier  5039.9856         3
# 3273  GBC Ibimaster 500 Manual ProClick Binding System  4946.3700        13
# 3232              Ibico EPK-21 Electric Binding System  4630.4755         5
# ...                                                ...        ...       ...
# 7101              Ibico EPK-21 Electric Binding System -2929.4845         5
# 9993         Lexmark MX611dhe Monochrome Laser Printer -3399.9800         5
# 3558         GBC DocuBind P400 Electric Binding System -3701.8928         8
# 683          Cubify CubeX 3D Printer Triple Head Print -3839.9904         4
# 5398         Cubify CubeX 3D Printer Double Head Print -6599.9780         5
#
#        Region      Sales      Segment   Ship Date       Ship Mode  \
# 8093  Central  17499.950    Corporate   10/9/2017  Standard Class
# 4905     West  13999.960     Consumer   3/25/2018     First Class
# 5297     East  10499.970     Consumer  11/22/2018  Standard Class
# 3273  Central   9892.740     Consumer  12/21/2017  Standard Class
# 3232  Central   9449.950     Consumer   9/28/2015  Standard Class
# ...       ...        ...          ...         ...             ...
# 7101  Central   1889.990    Corporate  12/13/2018  Standard Class
# 9993     West   2549.985  Home Office   4/23/2018  Standard Class
# 3558  Central   2177.584     Consumer   7/30/2015  Standard Class
# 683     South   7999.980    Corporate   11/4/2018        Same Day
# 5398     East   4499.985     Consumer   12/2/2017  Standard Class
#
#                State Sub-Category
# 8093         Indiana      Copiers
# 4905      Washington      Copiers
# 5297        Delaware      Copiers
# 3273        Michigan      Binders
# 3232       Minnesota      Binders
# ...              ...          ...
# 7101        Illinois      Binders
# 9993        Colorado     Machines
# 3558           Texas      Binders
# 683   North Carolina     Machines
# 5398            Ohio     Machines
#
# [9994 rows x 20 columns]

# %%
df_sample = df_sample.groupby(['Category', 'Sub-Category']).agg(Total_Profit = ('Profit', 'sum')).reset_index()

# %%
df_sample
# Out:
#            Category Sub-Category  Total_Profit
# 0         Furniture    Bookcases    -3472.5560
# 1         Furniture       Chairs    26590.1663
# 2         Furniture  Furnishings    13059.1436
# 3         Furniture       Tables   -17725.4811
# 4   Office Supplies   Appliances    18138.0054
# 5   Office Supplies          Art     6527.7870
# 6   Office Supplies      Binders    30221.7633
# 7   Office Supplies    Envelopes     6964.1767
# 8   Office Supplies    Fasteners      949.5182
# 9   Office Supplies       Labels     5546.2540
# 10  Office Supplies        Paper    34053.5693
# 11  Office Supplies      Storage    21278.8264
# 12  Office Supplies     Supplies    -1189.0995
# 13       Technology  Accessories    41936.6357
# 14       Technology      Copiers    55617.8249
# 15       Technology     Machines     3384.7569
# 16       Technology       Phones    44515.7306

# %%
df_sample.sort_values(by='Total_Profit', ascending=False) #High to Low
# Out:
#            Category Sub-Category  Total_Profit
# 14       Technology      Copiers    55617.8249
# 16       Technology       Phones    44515.7306
# 13       Technology  Accessories    41936.6357
# 10  Office Supplies        Paper    34053.5693
# 6   Office Supplies      Binders    30221.7633
# 1         Furniture       Chairs    26590.1663
# 11  Office Supplies      Storage    21278.8264
# 4   Office Supplies   Appliances    18138.0054
# 2         Furniture  Furnishings    13059.1436
# 7   Office Supplies    Envelopes     6964.1767
# 5   Office Supplies          Art     6527.7870
# 9   Office Supplies       Labels     5546.2540
# 15       Technology     Machines     3384.7569
# 8   Office Supplies    Fasteners      949.5182
# 12  Office Supplies     Supplies    -1189.0995
# 0         Furniture    Bookcases    -3472.5560
# 3         Furniture       Tables   -17725.4811
